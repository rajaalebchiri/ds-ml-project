# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Series

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])

# %%
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data[0:2]
# Out:
# 0    0.25
# 1    0.50
# dtype: float64

# %%
# different index values
data_abcd = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'b', 'c', 'd'])

# %%
data_abcd, data_abcd['b']
# Out:
# (a    0.25
#  b    0.50
#  c    0.75
#  d    1.00
#  dtype: float64,
#  0.5)

# %%
population_dict = {
    'California': 38332521,
    'Texas': 26448193,
    'New York': 19651127,
    'Florida': 19552860,
    'Illinois': 19552860
}

# %%
population = pd.Series(population_dict)

# %%
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      19552860
# dtype: int64

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
             'Florida': 170312, 'Illinois': 149995}

# %%
area = pd.Series(area_dict)

# %%
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({
    'Population': population,
    'area': area
})

# %%
states
# Out:
#             Population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      19552860  149995

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.columns
# Out:
# Index(['Population', 'area'], dtype='object')

# %%
states['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %% [markdown]
# ### Data Indexing and Selection

# %% [markdown]
# ####  Analyzing a Movie Dataset (Indexing and Selection)

# %%
# importing datasets
movies = pd.read_csv("./data/movies.csv")
links = pd.read_csv("./data/links.csv")
ratings = pd.read_csv("./data/ratings.csv")
tags = pd.read_csv("./data/tags.csv")

# %%
years = movies['title'].str.extract(r'\((\d{4})\)')
avg_ratings = ratings.groupby('movieId')['rating'].mean().reset_index()
user_votes = ratings.groupby('movieId')['userId'].count().reset_index(name='votes')

# %%
data = pd.DataFrame({
    'movie_id': movies['movieId'],
    'title': movies['title'].str.replace(r'\((\d{4})\)', '', regex=True),
    'year': years[0],
    'genre': movies['genres'],
    'rating': avg_ratings.set_index('movieId')['rating'],
    'votes': user_votes.set_index('movieId')['votes']
})

# %%
# convert year to numeric and handle any errors
data['year'] = pd.to_numeric(data['year'], errors='coerce')

# %%
data = data.reset_index(drop=True)

# %%
data.head()
# Out:
#    movie_id                         title    year
# 0       1.0                    Toy Story   1995.0  \
# 1       2.0                      Jumanji   1995.0
# 2       3.0             Grumpier Old Men   1995.0
# 3       4.0            Waiting to Exhale   1995.0
# 4       5.0  Father of the Bride Part II   1995.0
#
#                                          genre    rating  votes
# 0  Adventure|Animation|Children|Comedy|Fantasy       NaN    NaN
# 1                   Adventure|Children|Fantasy  3.920930  215.0
# 2                               Comedy|Romance  3.431818  110.0
# 3                         Comedy|Drama|Romance  3.259615   52.0
# 4                                       Comedy  2.357143    7.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14076 entries, 0 to 14075
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  9742 non-null   float64
#  1   title     9742 non-null   object
#  2   year      9729 non-null   float64
#  3   genre     9742 non-null   object
#  4   rating    9724 non-null   float64
#  5   votes     9724 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 659.9+ KB

# %%
# the first 5 movies
data.head()
# Out:
#    movie_id                         title    year
# 0       1.0                    Toy Story   1995.0  \
# 1       2.0                      Jumanji   1995.0
# 2       3.0             Grumpier Old Men   1995.0
# 3       4.0            Waiting to Exhale   1995.0
# 4       5.0  Father of the Bride Part II   1995.0
#
#                                          genre    rating  votes
# 0  Adventure|Animation|Children|Comedy|Fantasy       NaN    NaN
# 1                   Adventure|Children|Fantasy  3.920930  215.0
# 2                               Comedy|Romance  3.431818  110.0
# 3                         Comedy|Drama|Romance  3.259615   52.0
# 4                                       Comedy  2.357143    7.0

# %%
# the last 3 movies
data[-3:]
# Out:
#        movie_id title  year genre  rating  votes
# 14073       NaN   NaN   NaN   NaN     3.5    1.0
# 14074       NaN   NaN   NaN   NaN     3.5    1.0
# 14075       NaN   NaN   NaN   NaN     4.0    1.0

# %%
# select every other movie starting from the 2nd one
data[1::2]
# Out:
#        movie_id               title    year                       genre
# 1           2.0            Jumanji   1995.0  Adventure|Children|Fantasy  \
# 3           4.0  Waiting to Exhale   1995.0        Comedy|Drama|Romance
# 5           6.0               Heat   1995.0       Action|Crime|Thriller
# 7           8.0       Tom and Huck   1995.0          Adventure|Children
# 9          10.0          GoldenEye   1995.0   Action|Adventure|Thriller
# ...         ...                 ...     ...                         ...
# 14067       NaN                 NaN     NaN                         NaN
# 14069       NaN                 NaN     NaN                         NaN
# 14071       NaN                 NaN     NaN                         NaN
# 14073       NaN                 NaN     NaN                         NaN
# 14075       NaN                 NaN     NaN                         NaN
#
#          rating  votes
# 1      3.920930  215.0
# 3      3.259615   52.0
# 5      3.071429   49.0
# 7      3.185185   54.0
# 9      3.125000   16.0
# ...         ...    ...
# 14067  3.000000    1.0
# 14069  4.000000    1.0
# 14071  4.000000    1.0
# 14073  3.500000    1.0
# 14075  4.000000    1.0
#
# [7038 rows x 6 columns]

# %%
# select all information for the movie with 'movie_id' 100
data[data.movie_id == 100]
# Out:
#     movie_id       title    year           genre   rating  votes
# 88     100.0  City Hall   1996.0  Drama|Thriller  3.15625   16.0

# %%
# select the title and rating for movies with 'movie_id' 100, 200, and 300
data[data.movie_id.isin([100, 200, 300])][['title', 'rating']]
# Out:
#           title    rating
# 88   City Hall   3.156250
# 260  Quiz Show   4.231076

# %%
#  select all movies with a rating higher than 4.0
data[data.rating > 4.0]
# Out:
#        movie_id                                              title    year
# 28         29.0  City of Lost Children, The (Cité des enfants p...  1995.0  \
# 29         30.0     Shanghai Triad (Yao a yao yao dao waipo qiao)   1995.0
# 40         44.0                                     Mortal Kombat   1995.0
# 50         55.0                                           Georgia   1995.0
# 53         60.0                       Indian in the Cupboard, The   1995.0
# ...         ...                                                ...     ...
# 14045       NaN                                                NaN     NaN
# 14046       NaN                                                NaN     NaN
# 14049       NaN                                                NaN     NaN
# 14051       NaN                                                NaN     NaN
# 14065       NaN                                                NaN     NaN
#
#                                         genre    rating  votes
# 28     Adventure|Drama|Fantasy|Mystery|Sci-Fi  4.227273   11.0
# 29                                Crime|Drama  4.013158   38.0
# 40                   Action|Adventure|Fantasy  4.250000    2.0
# 50                                      Drama  4.237745  204.0
# 53                 Adventure|Children|Fantasy  5.000000    2.0
# ...                                       ...       ...    ...
# 14045                                     NaN  5.000000    1.0
# 14046                                     NaN  4.500000    1.0
# 14049                                     NaN  4.500000    1.0
# 14051                                     NaN  4.500000    1.0
# 14065                                     NaN  4.500000    1.0
#
# [1260 rows x 6 columns]

# %%
# select all movies from the year 2000 or later
data[data.year > 2000]
# Out:
#       movie_id                                title    year
# 3028    4052.0                           Antitrust   2001.0  \
# 3029    4053.0                         Double Take   2001.0
# 3030    4054.0                 Save the Last Dance   2001.0
# 3032    4056.0                         Pledge, The   2001.0
# 3040    4068.0                       Sugar & Spice   2001.0
# ...        ...                                  ...     ...
# 9736  193579.0   Jon Stewart Has Left the Building   2015.0
# 9737  193581.0  Black Butler: Book of the Atlantic   2017.0
# 9738  193583.0               No Game No Life: Zero   2017.0
# 9739  193585.0                               Flint   2017.0
# 9740  193587.0        Bungo Stray Dogs: Dead Apple   2018.0
#
#                                 genre    rating  votes
# 3028             Crime|Drama|Thriller  2.500000    2.0
# 3029                    Action|Comedy  3.250000    6.0
# 3030                    Drama|Romance  4.230769   13.0
# 3032     Crime|Drama|Mystery|Thriller  3.666667    6.0
# 3040                           Comedy  3.222222    9.0
# ...                               ...       ...    ...
# 9736                      Documentary       NaN    NaN
# 9737  Action|Animation|Comedy|Fantasy       NaN    NaN
# 9738         Animation|Comedy|Fantasy       NaN    NaN
# 9739                            Drama       NaN    NaN
# 9740                 Action|Animation       NaN    NaN
#
# [4497 rows x 6 columns]

# %%
data.genre.isnull().sum()
# Out:
# 4334

# %%
# select all movies that have 'Action' in their genre
action_movies = data[data.genre.fillna('').str.contains('Action', case=False, na=False)]

# %%
action_movies
# Out:
#       movie_id                                title    year
# 5          6.0                                Heat   1995.0  \
# 8          9.0                        Sudden Death   1995.0
# 9         10.0                           GoldenEye   1995.0
# 14        15.0                    Cutthroat Island   1995.0
# 19        20.0                         Money Train   1995.0
# ...        ...                                  ...     ...
# 9722  189547.0                        Iron Soldier   2010.0
# 9731  191005.0                             Gintama   2017.0
# 9732  193565.0                  Gintama: The Movie   2010.0
# 9737  193581.0  Black Butler: Book of the Atlantic   2017.0
# 9740  193587.0        Bungo Stray Dogs: Dead Apple   2018.0
#
#                                    genre    rating  votes
# 5                  Action|Crime|Thriller  3.071429   49.0
# 8                                 Action  2.875000    8.0
# 9              Action|Adventure|Thriller  3.125000   16.0
# 14              Action|Adventure|Romance  3.833333   18.0
# 19    Action|Comedy|Crime|Drama|Thriller  2.727273   88.0
# ...                                  ...       ...    ...
# 9722                       Action|Sci-Fi       NaN    NaN
# 9731      Action|Adventure|Comedy|Sci-Fi       NaN    NaN
# 9732      Action|Animation|Comedy|Sci-Fi       NaN    NaN
# 9737     Action|Animation|Comedy|Fantasy       NaN    NaN
# 9740                    Action|Animation       NaN    NaN
#
# [1828 rows x 6 columns]

# %%
# Select the 'title' and 'year' of the top 5 highest-rated movies
data.sort_values('rating', ascending=False).head(5)[['title', 'year']]
# Out:
#       title  year
# 11990   NaN   NaN
# 12441   NaN   NaN
# 13417   NaN   NaN
# 13428   NaN   NaN
# 13430   NaN   NaN
